# %% [markdown]
# <a href="https://colab.research.google.com/github/pandirib881-alt/Pandiri-.bhanu-prakash/blob/main/Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
    <title>CODTECH Internship Task - 4</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            background-color: #fefbe9;
            margin: 20px;
            color: #000;
        }
        .container {
            max-width: 800px;
            margin: auto;
            padding: 20px;
            border: 2px solid #000;
            background-color: #fff;
        }
        .header {
            display: flex;
            align-items: center;
            justify-content: space-between;
        }
        .logo {
            display: flex;
            align-items: center;
        }
        .logo svg {
            width: 50px;
            height: 50px;
            margin-right: 10px;
        }
        h1 {
            font-size: 2em;
            margin: 0;
        }
        .title {
            margin-top: 20px;
            font-size: 2em;
            font-weight: bold;
            color: #000;
        }
        .task {
            font-size: 1.5em;
            font-weight: bold;
            margin-top: 10px;
        }
        .recommendation {
            margin-top: 15px;
            font-weight: bold;
            font-size: 1.2em;
        }
        .instructions {
            margin-top: 20px;
            list-style-type: none;
            padding: 0;
        }
        .instructions li {
            background-color: #f0b24d;
            margin-bottom: 10px;
            padding: 10px;
            border-radius: 5px;
            font-weight: bold;
            display: flex;
            align-items: start;
        }
        .instructions li::before {
            content: "■";
            color: #000;
            font-weight: bold;
            display: inline-block;
            width: 20px;
            margin-right: 10px;
        }
        .footer {
            margin-top: 30px;
            display: flex;
            justify-content: space-between;
            align-items: center;
        }
        .certificate {
            background-color: #f26522;
            color: #fff;
            padding: 10px 20px;
            font-weight: bold;
            border-radius: 5px;
        }
        .codtech {
            background-color: #f26522;
            color: #fff;
            padding: 10px 20px;
            font-weight: bold;
            border-radius: 5px;
        }
        .note {
            margin-top: 10px;
            font-style: italic;
        }
        /* Add styles for images or icons if needed */
    </style>
</head>
<body>
    <div class="container">
        <div class="header">
            <div class="logo">
                <!-- Optional: insert SVG logo here -->
                <svg viewBox="0 0 64 64" fill="#f26522" xmlns="http://www.w3.org/2000/svg">
                    <circle cx="32" cy="32" r="32"/>
                </svg>
                <div style="font-weight:bold; font-size:1.5em;">CODTECH</div>
            </div>
        </div>
        <h1 class="title">INTERNSHIP</h1>
        <div class="task">TASK - 4</div>
        <div class="recommendation">RECOMMENDATION SYSTEM</div>
        <div class="instructions">
            <div style="background-color:#f0b24d; padding:10px; font-weight:bold; margin-bottom:10px;">INSTRUCTIONS:</div>
            <ul>
                <li>BUILD A RECOMMENDATION SYSTEM USING COLLABORATIVE FILTERING OR MATRIX FACTORIZATION TECHNIQUES.</li>
                <li>DELIVERABLE: A NOTEBOOK OR APP SHOWCASING RECOMMENDATION RESULTS AND EVALUATION METRICS.</li>
            </ul>
        </div>
        <div class="footer">
            <div class="certificate">COMPLETION CERTIFICATE WILL BE ISSUED ON YOUR INTERNSHIP END DATE.</div>
            <div class="codtech">CODTECH</div>
        </div>
    </div>
</body>
</html>
# Out:
#   File "/tmp/ipykernel_1491/3648722021.py", line 11
#     margin: 20px;
#              ^
# SyntaxError: invalid decimal literal
